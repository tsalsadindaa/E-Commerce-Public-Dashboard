# %% [markdown]
# # Proyek Analisis Data: [E-Commerce Public Dataset]
# - **Nama:** Tsalsa Dinda Maghfiroh
# - **Email:** mc180d5x0439@student.devacademy.id
# - **ID Dicoding:** MC180D5X0439

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Produk apa yang paling banyak dan paling sedikit terjual?
# - Bagaimana demografi pelanggan yang dimiliki?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# **Load tabel customers**

# %%
customers_df = pd.read_csv('https://raw.githubusercontent.com/tsalsadindaa/E-Commerce-Public-Dashboard/refs/heads/main/Data/customers_dataset.csv')
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# **Load tabel geolocation**

# %%
geolocation_df = pd.read_csv('https://raw.githubusercontent.com/tsalsadindaa/E-Commerce-Public-Dashboard/refs/heads/main/Data/geolocation_dataset.csv')
geolocation_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %% [markdown]
# **Load tabel order items**

# %%
order_items_df = pd.read_csv('https://raw.githubusercontent.com/tsalsadindaa/E-Commerce-Public-Dashboard/refs/heads/main/Data/order_items_dataset.csv')
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %% [markdown]
# **Load tabel order payments**

# %%
order_payments_df = pd.read_csv('https://raw.githubusercontent.com/tsalsadindaa/E-Commerce-Public-Dashboard/refs/heads/main/Data/order_payments_dataset.csv')
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %% [markdown]
# **Load tabel order reviews**

# %%
order_reviews_df = pd.read_csv('https://raw.githubusercontent.com/tsalsadindaa/E-Commerce-Public-Dashboard/refs/heads/main/Data/order_reviews_dataset.csv')
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %% [markdown]
# **Load tabel orders**

# %%
orders_df = pd.read_csv('https://raw.githubusercontent.com/tsalsadindaa/E-Commerce-Public-Dashboard/refs/heads/main/Data/orders_dataset.csv')
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# **Load tabel product category**

# %%
product_category_df = pd.read_csv('https://raw.githubusercontent.com/tsalsadindaa/E-Commerce-Public-Dashboard/refs/heads/main/Data/product_category_name_translation.csv')
product_category_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# **Load tabel products**

# %%
products_df = pd.read_csv('https://raw.githubusercontent.com/tsalsadindaa/E-Commerce-Public-Dashboard/refs/heads/main/Data/products_dataset.csv')
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# **Load tabel sellers**

# %%
sellers_df = pd.read_csv('https://raw.githubusercontent.com/tsalsadindaa/E-Commerce-Public-Dashboard/refs/heads/main/Data/sellers_dataset.csv')
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# **Insight:**
# - Semua data yang dibutuhkan telah berhasil dimuat

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# **Menilai data customers**

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
print("Jumlah duplikasi: ",customers_df.duplicated().sum())
print("Jumlah missing value: ",customers_df.isna().sum().sum())
customers_df.describe()
# Out:
# Jumlah duplikasi:  0
# Jumlah missing value:  0
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %%
geolocation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
print("Jumlah duplikasi: ",geolocation_df.duplicated().sum())
print("Jumlah missing value: ",geolocation_df.isna().sum().sum())
geolocation_df.describe()
# Out:
# Jumlah duplikasi:  261831
# Jumlah missing value:  0
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
print("Jumlah duplikasi: ",order_items_df.duplicated().sum())
print("Jumlah missing value: ",order_items_df.isna().sum().sum())
order_items_df.describe()
# Out:
# Jumlah duplikasi:  0
# Jumlah missing value:  0
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %%
order_payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
print("Jumlah duplikasi: ",order_payments_df.duplicated().sum())
print("Jumlah missing value: ",order_payments_df.isna().sum().sum())
order_payments_df.describe()
# Out:
# Jumlah duplikasi:  0
# Jumlah missing value:  0
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
print("Jumlah duplikasi: ",order_reviews_df.duplicated().sum())
print("Jumlah missing value: ",order_reviews_df.isna().sum().sum())
order_reviews_df.describe()
# Out:
# Jumlah duplikasi:  0
# Jumlah missing value:  145903
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
print("Jumlah duplikasi: ",orders_df.duplicated().sum())
print("Jumlah missing value: ",orders_df.isna().sum().sum())
orders_df.describe()
# Out:
# Jumlah duplikasi:  0
# Jumlah missing value:  4908
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %%
product_category_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
print("Jumlah duplikasi: ",product_category_df.duplicated().sum())
print("Jumlah missing value: ",product_category_df.isna().sum().sum())
product_category_df.describe()
# Out:
# Jumlah duplikasi:  0
# Jumlah missing value:  0
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
print("Jumlah duplikasi: ",products_df.duplicated().sum())
print("Jumlah missing value: ",products_df.isna().sum().sum())
products_df.describe()
# Out:
# Jumlah duplikasi:  0
# Jumlah missing value:  2448
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# ...

# %%
sellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
print("Jumlah duplikasi: ",sellers_df.duplicated().sum())
print("Jumlah missing value: ",sellers_df.isna().sum().sum())
sellers_df.describe()
# Out:
# Jumlah duplikasi:  0
# Jumlah missing value:  0
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %% [markdown]
# **Insight:**
# - Pada data geolocation_df ditemukan duplikasi sebanyak 261831 data
# - Pada data order_reviews_df ditemukan missing value sebanyak 145903 data
# - Pada data orders_df ditemukan missing value sebanyak 4908 data
# - Pada data products_df ditemukan missing value sebanyak 2448 data

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# **Membersihkan data geolocation**

# %%
geolocation_df.drop_duplicates(inplace=True)
print("Jumlah duplikasi: ",geolocation_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# **Membersihkan data order reviews**

# %%
order_reviews_df[order_reviews_df.review_comment_title.isna()]
order_reviews_df[order_reviews_df.review_comment_message.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 5      15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 6      07f9bee5d1b850860defd761afa7ff16  e48aa0d2dcec3a2e87348811bcfdf22b
# ...                                 ...                               ...
# 99217  c6b270c61f67c9f7cb07d84ea8aeaf8b  48f7ee67313eda32bfcf5b9c1dd9522d
# 99218  af2dc0519de6e0720ef0c74292fb4114  d699c734a0b1c8111f2272a3f36d398c
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
#
#        review_score review_comment_title review_comment_message  \
# ...

# %%
order_reviews_df.fillna(value={'review_comment_title':'No Title','review_comment_message':'No Message'},inplace=True)
print("Jumlah missing value: ",order_reviews_df.isna().sum().sum())
# Out:
# Jumlah missing value:  0

# %% [markdown]
# **Membersihkan data orders**

# %%
orders_df[orders_df.order_approved_at.isna()]
orders_df[orders_df.order_delivered_carrier_date.isna()]
orders_df[orders_df.order_delivered_customer_date.isna()]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 44     ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 154    6942b8da583c2f9957e990d028607019  52006a9383bf149a4fb24226b173106f
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
orders_df.fillna(value={'order_approved_at':'No Date','order_delivered_carrier_date':'No Date','order_delivered_customer_date':'No Date'},inplace=True)
print("Jumlah missing value: ",orders_df.isna().sum().sum())
# Out:
# Jumlah missing value:  0

# %% [markdown]
# **Membersihkan data products**

# %%
products_df[products_df.product_category_name.isna()]
products_df[products_df.product_name_lenght.isna()]
products_df[products_df.product_description_lenght.isna()]
products_df[products_df.product_photos_qty.isna()]
products_df[products_df.product_weight_g.isna()]
products_df[products_df.product_length_cm.isna()]
products_df[products_df.product_height_cm.isna()]
products_df[products_df.product_width_cm.isna()]
# Out:
#                              product_id product_category_name  \
# 8578   09ff539a621711667c43eba6a3bd8466                 bebes
# 18851  5eb564652db742ff8f28759cd8d2652a                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 8578                  60.0                       865.0                 3.0
# 18851                  NaN                         NaN                 NaN
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 8578                NaN                NaN                NaN
# 18851               NaN                NaN                NaN
#
#        product_width_cm
# 8578                NaN
# 18851               NaN

# %%
products_df.fillna(value={'product_category_name':'No Category','product_name_lenght':0,'product_description_lenght':0,'product_photos_qty':0,'product_weight_g':0,'product_length_cm':0,'product_height_cm':0,'product_width_cm':0},inplace=True)
print("Jumlah missing value: ",products_df.isna().sum().sum())
# Out:
# Jumlah missing value:  0

# %% [markdown]
# **Insight:**
# - Pada data geolocation_df sudah tidak ditemukan duplikasi data
# - Pada data order_reviews_df, orders_df, dan products_df sudah tidak ditemukan missing value data

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %% [markdown]
# **Eksplorasi data customers**

# %%
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
customers_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#   customer_state  customer_id
# 0             SP        41746
# 1             RJ        12852
# 2             MG        11635
# 3             RS         5466
# 4             PR         5045
# 5             SC         3637
# 6             BA         3380
# 7             DF         2140
# 8             ES         2033
# 9             GO         2020

# %%
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#            customer_city  customer_id
# 0              sao paulo        15540
# 1         rio de janeiro         6882
# 2         belo horizonte         2773
# 3               brasilia         2131
# 4               curitiba         1521
# 5               campinas         1444
# 6           porto alegre         1379
# 7               salvador         1245
# 8              guarulhos         1189
# 9  sao bernardo do campo          938

# %% [markdown]
# **Eksplorasi data geolocation**

# %%
geolocation_df.describe(include="all")
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# count                 738332.000000    738332.000000    738332.000000
# unique                          NaN              NaN              NaN
# top                             NaN              NaN              NaN
# freq                            NaN              NaN              NaN
# mean                   38316.086800       -20.998353       -46.461098
# std                    30632.496675         5.892315         4.393705
# min                     1001.000000       -36.605374      -101.466766
# 25%                    12600.000000       -23.603061       -48.867822
# 50%                    29144.000000       -22.873588       -46.647278
# 75%                    65950.000000       -19.923336       -43.836974
# max                    99990.000000        45.065933       121.105394
#
#        geolocation_city geolocation_state
# count            738332            738332
# ...

# %% [markdown]
# **Eksplorasi data order items**

# %%
order_items_df.describe(include="all")
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# std                                  NaN       0.705124
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %%
order_items_df.groupby(by="product_id").agg(
    min_price=("price", "min"),
    max_price=("price", "max")
)
# Out:
#                                   min_price  max_price
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38     101.65     101.65
# 00088930e925c41fd95ebfe695fd2655     129.90     129.90
# 0009406fd7479715e4bef61dd91f2462     229.00     229.00
# 000b8f95fcb9e0096488278317764d19      58.90      58.90
# 000d9be29b5207b54e86aa1b1ac54872     199.00     199.00
# ...                                     ...        ...
# fff6177642830a9a94a0f2cba5e476d1     109.99     119.99
# fff81cc3158d2725c0655ab9ba0f712c      90.00      90.00
# fff9553ac224cec9d15d49f5a263411f      32.00      32.00
# fffdb2d0ec8d6a61f0a0a0db3f25b441      29.99      34.99
# fffe9eeff12fcbd74a2f2b007dde0c58     249.99     249.99
#
# [32951 rows x 2 columns]

# %%
order_estimated_delivery_date = pd.to_datetime(order_items_df['shipping_limit_date'])
order_estimated_delivery_date.dt.year.value_counts()
# Out:
# shipping_limit_date
# 2018    62511
# 2017    49765
# 2016      370
# 2020        4
# Name: count, dtype: int64

# %%
customer_id_in_orders_df = orders_df.customer_id.tolist()
customers_df["status"] = customers_df["customer_id"].apply(lambda x:"active" if x in customer_id_in_orders_df else "Non Active")
customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 24056  73c5348a67dcfe51d332594ab795021f  4f26b12d535556bbf0f6b04e2216c35c
# 17041  06293b07f2a65667ea6eca6eb2e0f25f  c5e45bc8a770bd25b7dc44073b5ae29a
# 17521  9d394287cc0e0045079b25d2df4adf87  d60483078c0c81748581f80d355bbcba
# 62077  87ef890f6ee57134f134f76f5c5d6b53  69068f0eac0d07b0eb647fe5dd20e1bc
# 50374  6f1619fe6c0faacdee5d55e1204d9128  b2bf5942ebc2c60cba4b07707a51bf2d
#
#        customer_zip_code_prefix   customer_city customer_state  status
# 24056                     30411  belo horizonte             MG  active
# 17041                     11500         cubatao             SP  active
# 17521                      7140       guarulhos             SP  active
# 62077                     57540     mata grande             AL  active
# 50374                      4567       sao paulo             SP  active

# %%
customers_df.groupby(by="status").customer_id.count()
# Out:
# status
# active    99441
# Name: customer_id, dtype: int64

# %% [markdown]
# **Eksplorasi data order payments**

# %%
order_payments_df.describe(include="all")
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# ...

# %%
order_payments_df.groupby(by="payment_type").order_id.count()
# Out:
# payment_type
# boleto         19784
# credit_card    76795
# debit_card      1529
# not_defined        3
# voucher         5775
# Name: order_id, dtype: int64

# %% [markdown]
# **Eksplorasi data order reviews**

# %%
order_reviews_df.describe(include="all")
# Out:
#                                review_id                          order_id  \
# count                              99224                             99224
# unique                             98410                             98673
# top     7b606b0d57b078384f0b58eac1d41d78  c88b1d1b157a9999ce368f218a407141
# freq                                   3                                 3
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         review_score review_comment_title review_comment_message  \
# ...

# %% [markdown]
# **Eksplorasi data orders**

# %%
orders_df.describe(include="all")
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp order_approved_at  \
# count         99441                    99441             99441
# unique            8                    98875             90734
# top       delivered      2018-04-11 10:48:14           No Date
# freq          96478                        3               160
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         99441                         99441
# unique                        81019                         95665
# top                         No Date                       No Date
# ...

# %% [markdown]
# **Eksplorasi data product category**

# %%
product_category_df.describe(include="all")
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %% [markdown]
# **Eksplorasi data products**

# %%
products_df.describe(include="all")
# Out:
#                               product_id product_category_name  \
# count                              32951                 32951
# unique                             32951                    74
# top     1e9e8ef04dbcff4541ed26657ea517e5       cama_mesa_banho
# freq                                   1                  3029
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# count          32951.000000                32951.000000        32951.000000
# ...

# %% [markdown]
# **Eksplorasi data sellers**

# %%
sellers_df.describe(include="all")
# Out:
#                                seller_id  seller_zip_code_prefix seller_city  \
# count                               3095             3095.000000        3095
# unique                              3095                     NaN         611
# top     3442f8959a84dea7ee197c632cb2df15                     NaN   sao paulo
# freq                                   1                     NaN         694
# mean                                 NaN            32291.059451         NaN
# std                                  NaN            32713.453830         NaN
# min                                  NaN             1001.000000         NaN
# 25%                                  NaN             7093.500000         NaN
# 50%                                  NaN            14940.000000         NaN
# 75%                                  NaN            64552.500000         NaN
# max                                  NaN            99730.000000         NaN
#
#        seller_state
# count          3095
# ...

# %%
sellers_df.groupby(by="seller_state").seller_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#   seller_state  seller_id
# 0           SP       1849
# 1           PR        349
# 2           MG        244
# 3           SC        190
# 4           RJ        171
# 5           RS        129
# 6           GO         40
# 7           DF         30
# 8           ES         23
# 9           BA         19

# %%
sellers_df.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#       seller_city  seller_id
# 0       sao paulo        694
# 1        curitiba        127
# 2  rio de janeiro         96
# 3  belo horizonte         68
# 4  ribeirao preto         52
# 5       guarulhos         50
# 6        ibitinga         49
# 7     santo andre         45
# 8        campinas         41
# 9         maringa         40

# %%
# Gabungkan semua data penting dengan nama all_data
all_data = pd.merge(orders_df, customers_df, on='customer_id', how='left')
all_data = pd.merge(all_data, order_items_df, on='order_id', how='left')
all_data = pd.merge(all_data, products_df, on='product_id', how='left')
all_data = pd.merge(all_data, sellers_df, on='seller_id', how='left')
all_data = pd.merge(all_data, order_payments_df, on='order_id', how='left')
all_data = pd.merge(all_data, order_reviews_df, on='order_id', how='left')
all_data = pd.merge(all_data, product_category_df, on='product_category_name', how='left')

geolocation_agg = geolocation_df.groupby('geolocation_zip_code_prefix').agg({
    'geolocation_lat': 'mean',
    'geolocation_lng': 'mean'
}).reset_index()
all_data = pd.merge(all_data, geolocation_agg, left_on='customer_zip_code_prefix', right_on='geolocation_zip_code_prefix', how='left')

timestamp_columns = ['order_purchase_timestamp', 'order_approved_at',
                    'order_delivered_carrier_date', 'order_delivered_customer_date',
                    'order_estimated_delivery_date']
for col in timestamp_columns:
  all_data[col] = pd.to_datetime(all_data[col], errors='coerce')

all_data['order_purchase_timestamp'] = pd.to_datetime(all_data['order_purchase_timestamp'])

all_data['order_month'] = all_data['order_purchase_timestamp'].dt.month
all_data['order_year'] = all_data['order_purchase_timestamp'].dt.year
all_data['order_dayofweek'] = all_data['order_purchase_timestamp'].dt.dayofweek
all_data['total_order_value'] = all_data['price'] + all_data['freight_value']

# %%
# Simpan all_data ke dalam file CSV
all_data.to_csv('all_data.csv', index=False)
print("DataFrame all_data berhasil digabungkan dan disimpan ke all_data.csv")
# Out:
# DataFrame all_data berhasil digabungkan dan disimpan ke all_data.csv

# %% [markdown]
# **Insight:**
# - Customer terbanyak ada di provinsi SP dan kota sao palo
# - tipe pembayaran paling banyak adalah dengan menggunakan kartu kredit
# - semua pelanggan adalah aktif (pernah melakukan minimal sekali pembayaran)
# - Menggabungkan data penting kedalam all_data.csv

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Produk apa yang paling banyak dan paling sedikit terjual?

# %%
sum_order_items_df = all_data.groupby("product_category_name_english").order_item_id.sum().sort_values(ascending=False).reset_index()

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#728CD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="order_item_id", y="product_category_name_english",
            data=sum_order_items_df.sort_values(by="order_item_id", ascending=False).head(5),
            palette=colors, ax=ax[0], hue="product_category_name_english", legend=False)
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Produk Teratas", loc="center", fontsize=15)
ax[0].tick_params(axis='y', labelsize=12)

sns.barplot(x="order_item_id", y="product_category_name_english",
            data=sum_order_items_df.head(5),
            palette=colors, ax=ax[1], hue="product_category_name_english", legend=False)
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Produk Terbawah", loc="center", fontsize=15)

plt.suptitle("Top 5 Produk Teratas dan Terbawah Berdasarkan Penjualan", fontsize=20)
plt.show()

# %% [markdown]
# **Insight:**
# - 5 produk teratas adalah bed_bath_table, health_beauty, sport_leisure, furniture_decor, computers_accesories
# - 5 produk terbawah adalah art_and_craftmanship, la_cruisine, cds_dvds_musicals, fashion_childrens_clothes, security_and_services

# %% [markdown]
# ### Pertanyaan 2: Bagaimana demografi pelanggan yang dimiliki

# %% [markdown]
# **Berdasarkan state**

# %%
bystate_df = all_data.groupby(by="customer_state").customer_id.nunique().reset_index()
bystate_df.rename(columns={"customer_id": "customer_count"}, inplace=True)
bystate_df = bystate_df.sort_values(by="customer_count", ascending=False).head(10)

plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(
    x="customer_count",
    y="customer_state",
    data=bystate_df,
    palette=colors_,
    hue="customer_state",
    legend=False
)
plt.title("Jumlah Pelanggan Berdasarkan Provinsi", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()

# %% [markdown]
# **Berdasarkan City**

# %%
bycity_df = all_data.groupby(by="customer_city").customer_id.nunique().reset_index()
bycity_df.rename(columns={"customer_id": "customer_count"}, inplace=True)
bycity_df = bycity_df.sort_values(by="customer_count", ascending=False).head(10)

plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(
    x="customer_count",
    y="customer_city",
    data=bycity_df,
    palette=colors_,
    hue="customer_city",
    legend=False
)
plt.title("Jumlah Pelanggan Berdasarkan Kota", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()

# %% [markdown]
# **Insight:**
# - Provinsi dengan jumlah pelanggan terbanyak ada di provinsi SP
# - Kota dengan jumlah pelanggan terbanyak ada di kota Sao Paulo

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %%
# Pastikan kolom order_purchase_timestamp dalam format datetime
all_data["order_purchase_timestamp"] = pd.to_datetime(all_data["order_purchase_timestamp"])

rfm_df = all_data.groupby(by="customer_zip_code_prefix", as_index=False).agg({
    "order_purchase_timestamp": "max",
    "order_id": "nunique",
    "price": "sum"
})

rfm_df.columns = ["customer_zip_code_prefix", "max_order_timestamp", "frequency", "monetary"]

# Pastikan kolom max_order_timestamp dalam format datetime
rfm_df["max_order_timestamp"] = pd.to_datetime(rfm_df["max_order_timestamp"])

rfm_df["max_order_timestamp"] = rfm_df["max_order_timestamp"].dt.date
recent_date = all_data["order_purchase_timestamp"].dt.date.max()
rfm_df["recency"] = rfm_df["max_order_timestamp"].apply(lambda x: (recent_date - x).days)

rfm_df.drop("max_order_timestamp", axis=1, inplace=True)
rfm_df.head()
# Out:
#    customer_zip_code_prefix  frequency  monetary  recency
# 0                      1003          1     89.99      160
# 1                      1004          2    178.99      126
# 2                      1005          6    490.59       64
# 3                      1006          2    834.80      188
# 4                      1007          4    455.48       54

# %%
rfm_df.describe()
# Out:
#        customer_zip_code_prefix     frequency      monetary       recency
# count              14994.000000  14994.000000  14994.000000  14994.000000
# mean               40443.814793      6.632053    951.960761    165.866613
# std                31360.066706      8.381904   1375.537267    123.779555
# min                 1003.000000      1.000000      0.000000      0.000000
# 25%                 9641.250000      2.000000    184.905000     73.000000
# 50%                35248.500000      4.000000    486.365000    120.000000
# 75%                70336.750000      8.000000   1166.490000    218.000000
# max                99990.000000    142.000000  24479.800000    743.000000

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(20, 6))

colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]

sns.barplot(y="recency", x="customer_zip_code_prefix", data=rfm_df.sort_values(by="recency", ascending=True).head(5), hue="customer_zip_code_prefix", palette=colors, ax=ax[0], legend=False)
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis ='x', labelsize=15)

sns.barplot(y="frequency", x="customer_zip_code_prefix", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), hue="customer_zip_code_prefix", palette=colors, ax=ax[1], legend=False)
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=15)

sns.barplot(y="monetary", x="customer_zip_code_prefix", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), hue="customer_zip_code_prefix", palette=colors, ax=ax[2], legend=False)
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=15)

plt.suptitle("Pelanggan Terbaik Berdasarkan Parameter RFM (customer_zip_code_prefix)", fontsize=20)
plt.show()

# %% [markdown]
# **Insight:**
# - Pelanggan paling baru adalah pelanggan dengan zip code prefix 64600
# - Pelanggan paling sering membeli adalah pelanggan dengan zip code prefix 22790
# - Pelanggan paling banyak mengeluarkan uang adalah pelanggan dengan zip code prefix 24220

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1: Grafik menunjukkan bahwa produk yang paling sering terjual adalah bed_bath_table dan produk yang paling jarang terbeli adalah security_and_services
#
# - Conclution pertanyaan 2 : Grafik menunjukkan provinsi dengan jumlah pelanggan terbanyak adalah provinsi SP dan kota dengan jumlah pelanggan terbanyak adalah kota Sao Paulo
#
# - Conclution analisis lanjutan : grafik menunjukkan bahwa pelanggan yang paling baru membeli barang adalah pelanggan dengan zip coe 64600, lalu pelanggan yang paling sering membeli barang adalah pelanggan dengan zip code prefix 22790, dan pelanggan yang paling banyak mengeluarkan uang adalah pelanggan dengan zip code 24220
